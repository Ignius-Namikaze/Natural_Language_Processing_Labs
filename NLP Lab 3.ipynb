# %% [markdown]
# # Using NLTK

# %% [markdown]
# ## a.	To access Gutenberg corpus from nltk, list all the texts available

# %%
import nltk
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
caesar = nltk.corpus.gutenberg.words('shakespeare-caesar.txt')
len(caesar)
# Out:
# 25833

# %%
caesar = nltk.Text(nltk.corpus.gutenberg.words('shakespeare-caesar.txt'))
caesar.concordance("Caesar")
# Out:
# Displaying 25 of 190 matches:
# [ The Tragedie of Julius Caesar by William Shakespeare 1599 ] Actus
# ndeede sir , we make Holyday to see Caesar , and to reioyce in his Triumph Mur
# uile fearefulnesse . Exeunt . Enter Caesar , Antony for the Course , Calphurni
# Caes . Calphurnia Cask . Peace ho , Caesar speakes Caes . Calphurnia Calp . He
# curse Ant . I shall remember , When Caesar sayes , Do this ; it is perform ' d
# , and leaue no Ceremony out Sooth . Caesar Caes . Ha ? Who calles ? Cask . Bid
# shriller then all the Musicke Cry , Caesar : Speake , Caesar is turn ' d to he
# the Musicke Cry , Caesar : Speake , Caesar is turn ' d to heare Sooth . Beware
#  , come from the throng , look vpon Caesar Caes . What sayst thou to me now ?
# espect in Rome , ( Except immortall Caesar ) speaking of Brutus , And groaning
# ng ? I do feare , the People choose Caesar For their King Cassi . I , do you f
# as I my selfe . I was borne free as Caesar , so were you , We both haue fed as
# ...

# %% [markdown]
# ## b.	To write a function to know the following about each text in the corpus using raw(), sents(),words() functions from nltk
# ### a.	Total number of words
# ### b.	Total number of characters
# ### c.	Total number of sentences
# ### d.	Average characters per words
# ### e.	Type Token Ratio (TTR) and comment about lexical richness of each text

# %%
from nltk.corpus import gutenberg
gutenberg.fileids()
emma = gutenberg.words('shakespeare-caesar.txt')

# %%
for fileid in gutenberg.fileids():
     num_chars = len(gutenberg.raw(fileid))
     num_words = len(gutenberg.words(fileid))
     num_sents = len(gutenberg.sents(fileid))
     num_vocab = len(set(w.lower() for w in gutenberg.words(fileid)))
     print(num_chars, num_sents, num_vocab, fileid)
     print(round(num_chars/num_words), round(num_words/num_sents), round(num_words/num_vocab), fileid)
# Out:
# 887071 7717 7344 austen-emma.txt
# 5 25 26 austen-emma.txt
# 466292 3747 5835 austen-persuasion.txt
# 5 26 17 austen-persuasion.txt
# 673022 4999 6403 austen-sense.txt
# 5 28 22 austen-sense.txt
# 4332554 30103 12767 bible-kjv.txt
# 4 34 79 bible-kjv.txt
# 38153 438 1535 blake-poems.txt
# 5 19 5 blake-poems.txt
# 249439 2863 3940 bryant-stories.txt
# 4 19 14 bryant-stories.txt
# 84663 1054 1559 burgess-busterbrown.txt
# 4 18 12 burgess-busterbrown.txt
# 144395 1703 2636 carroll-alice.txt
# 4 20 13 carroll-alice.txt
# 457450 4779 8335 chesterton-ball.txt
# 5 20 12 chesterton-ball.txt
# 406629 3806 7794 chesterton-brown.txt
# 5 23 11 chesterton-brown.txt
# 320525 3728 6349 chesterton-thursday.txt
# 5 19 11 chesterton-thursday.txt
# 935158 10230 8447 edgeworth-parents.txt
# 4 21 25 edgeworth-parents.txt
# 1242990 10059 17231 melville-moby_dick.txt
# 5 26 15 melville-moby_dick.txt
# 468220 1851 9021 milton-paradise.txt
# 5 52 11 milton-paradise.txt
# ...

# %%
caesar_sentences = gutenberg.sents('shakespeare-caesar.txt')
caesar_sentences
# Out:
# [['[', 'The', 'Tragedie', 'of', 'Julius', 'Caesar', 'by', 'William', 'Shakespeare', '1599', ']'], ['Actus', 'Primus', '.'], ...]

# %%
caesar_sentences[1116]
# Out:
# ['1', 'This', 'Caesar', 'was', 'a', 'Tyrant']

# %%
longest_len = max(len(s) for s in caesar_sentences)
[s for s in caesar_sentences if len(s) == longest_len]
# Out:
# [['Ouer',
#   'thy',
#   'wounds',
#   ',',
#   'now',
#   'do',
#   'I',
#   'Prophesie',
#   ',',
#   '(',
#   'Which',
#   'like',
#   'dumbe',
#   'mouthes',
#   'do',
#   'ope',
#   'their',
#   'Ruby',
#   'lips',
#   ',',
#   'To',
#   'begge',
#   'the',
#   'voyce',
#   'and',
#   'vtterance',
#   'of',
#   'my',
#   'Tongue',
#   ')',
#   'A',
#   'Curse',
#   'shall',
#   'light',
#   'vpon',
#   'the',
#   'limbes',
#   'of',
#   'men',
#   ';',
#   'Domesticke',
#   'Fury',
#   ',',
#   'and',
#   'fierce',
#   'Ciuill',
#   'strife',
#   ',',
#   'Shall',
#   'cumber',
#   'all',
#   'the',
#   'parts',
#   'of',
#   'Italy',
#   ':',
#   'Blood',
#   'and',
#   'destruction',
#   'shall',
#   'be',
#   'so',
#   'in',
#   'vse',
#   ',',
#   'And',
#   'dreadfull',
#   'Obiects',
#   'so',
#   'familiar',
#   ',',
#   'That',
#   'Mothers',
#   'shall',
#   'but',
#   'smile',
#   ',',
#   'when',
#   'they',
#   'behold',
#   'Their',
#   'Infants',
#   'quartered',
# ...

# %% [markdown]
# ## c.	To access Brown corpus from nltk and list all the available texts

# %%
from nltk.corpus import brown
files= brown.fileids()
print(files)
# Out:
# ['ca01', 'ca02', 'ca03', 'ca04', 'ca05', 'ca06', 'ca07', 'ca08', 'ca09', 'ca10', 'ca11', 'ca12', 'ca13', 'ca14', 'ca15', 'ca16', 'ca17', 'ca18', 'ca19', 'ca20', 'ca21', 'ca22', 'ca23', 'ca24', 'ca25', 'ca26', 'ca27', 'ca28', 'ca29', 'ca30', 'ca31', 'ca32', 'ca33', 'ca34', 'ca35', 'ca36', 'ca37', 'ca38', 'ca39', 'ca40', 'ca41', 'ca42', 'ca43', 'ca44', 'cb01', 'cb02', 'cb03', 'cb04', 'cb05', 'cb06', 'cb07', 'cb08', 'cb09', 'cb10', 'cb11', 'cb12', 'cb13', 'cb14', 'cb15', 'cb16', 'cb17', 'cb18', 'cb19', 'cb20', 'cb21', 'cb22', 'cb23', 'cb24', 'cb25', 'cb26', 'cb27', 'cc01', 'cc02', 'cc03', 'cc04', 'cc05', 'cc06', 'cc07', 'cc08', 'cc09', 'cc10', 'cc11', 'cc12', 'cc13', 'cc14', 'cc15', 'cc16', 'cc17', 'cd01', 'cd02', 'cd03', 'cd04', 'cd05', 'cd06', 'cd07', 'cd08', 'cd09', 'cd10', 'cd11', 'cd12', 'cd13', 'cd14', 'cd15', 'cd16', 'cd17', 'ce01', 'ce02', 'ce03', 'ce04', 'ce05', 'ce06', 'ce07', 'ce08', 'ce09', 'ce10', 'ce11', 'ce12', 'ce13', 'ce14', 'ce15', 'ce16', 'ce17', 'ce18', 'ce19', 'ce20
# ...

# %%
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
brown.words(categories='news')

brown.words(fileids=['cg22'])
# Out:
# ['Does', 'our', 'society', 'have', 'a', 'runaway', ',', ...]

# %% [markdown]
# # Access text from web

# %%
from urllib import request
url = "http://www.gutenberg.org/files/2554/2554-0.txt"
response = request.urlopen(url)
raw = response.read().decode('utf8')
print(type(raw))
print(len(raw))
print(raw[1000:1200])
# Out:
# <class 'str'>
# 1176812
# CE
#
# A few words about Dostoevsky himself may help the English reader to
# understand his work.
#
# Dostoevsky was the son of a doctor. His parents were very hard-working
# and deeply religious people,

# %%
from nltk import word_tokenize

# %%
f = open('caesar.txt')
raw = f.read()
tokens = word_tokenize(raw)

# %%
pip install wordcloud
# Out:
# ...
#      ------------------------------------ 152.1/152.1 kB 454.7 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
comment_words = ''
stopwords = set(STOPWORDS)
for val in caesar_sentences:
     
    val = str(val)
 
    tokens = val.split()

    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)

# %%
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
